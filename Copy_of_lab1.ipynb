# %% [markdown]
# <a href="https://colab.research.google.com/github/Musa236-6/farm/blob/main/Copy_of_lab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello from google colab!")
1+1
# Out:
# Hello from google colab!
# 2
